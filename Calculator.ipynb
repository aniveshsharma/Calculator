# %%
#importing Dependencies
import customtkinter
import tkinter

# %%
customtkinter.set_appearance_mode("light")
customtkinter.set_default_color_theme("dark-blue")

root = customtkinter.CTk()
root.resizable(False,False)
root.geometry("385x490")

equation = ""
def Calculator():
    pass

def show(value):
    global equation
    equation+=value
    display.config(text=equation)

def clear():
    global equation
    equation=""
    display.config(text=equation)

def calculate():
    global equation
    result = ""
    if equation != "":
        try:
            result=eval(equation)
        except:
            result="error"
            equation=""
        display.config(text=result)


#Frame
frame = customtkinter.CTkFrame(master=root)
frame.pack(pady=20,padx=30,fill="both", expand=True)
#Title Calculator
label = customtkinter.CTkLabel(master=frame,text="Calculator", font=("serif",24,"bold"),text_color="green")
label.pack(padx=10,pady=20)
#Displaybox
display = tkinter.Label(master=frame,text="",width=45,height=2,font=("serif",20,"bold"),bg="white")
display.pack(padx=10,pady=2)
#Buttons
customtkinter.CTkButton(master=frame , text = "%" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: show("%")).place(x=15,y=150)
customtkinter.CTkButton(master=frame , text = "CE" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: clear()).place(x=90,y=150)
customtkinter.CTkButton(master=frame , text = "C" ,font=("serif",20,"bold"),width=65,height=35,command=lambda:clear()).place(x=165,y=150)
customtkinter.CTkButton(master=frame , text = "Del" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: clear()).place(x=240,y=150)
customtkinter.CTkButton(master=frame , text = "1" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: show("1")).place(x=15,y=200)
customtkinter.CTkButton(master=frame , text = "2" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: show("2")).place(x=90,y=200)
customtkinter.CTkButton(master=frame , text = "3" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: show("3")).place(x=165,y=200)
customtkinter.CTkButton(master=frame , text = "+" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: show("+")).place(x=240,y=200)
customtkinter.CTkButton(master=frame , text = "4" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: show("4")).place(x=15,y=250)
customtkinter.CTkButton(master=frame , text = "5" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: show("5")).place(x=90,y=250)
customtkinter.CTkButton(master=frame , text = "6" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: show("6")).place(x=165,y=250)
customtkinter.CTkButton(master=frame,text="-",font=("serif",20,"bold"),width=65,height=30,command=lambda: show("-")).place(x=240,y=250)
customtkinter.CTkButton(master=frame , text = "7" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: show("7")).place(x=15,y=300)
customtkinter.CTkButton(master=frame , text = "8" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: show("8")).place(x=90,y=300)
customtkinter.CTkButton(master=frame , text = "9" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: show("9")).place(x=165,y=300)
customtkinter.CTkButton(master=frame,text="*",font=("serif",20,"bold"),width=65,height=35,command=lambda: show("*")).place(x=240,y=300)
customtkinter.CTkButton(master=frame , text = "0" ,font=("serif",20,"bold"),width=65,height=35,command=lambda: show("0")).place(x=15,y=350)
customtkinter.CTkButton(master=frame,text="+/-",font=("serif",20,"bold"),width=65,height=35,command=lambda: show("-")).place(x=90,y=350)
customtkinter.CTkButton(master=frame,text=".",font=("serif",20,"bold"),width=65,height=35,command=lambda: show(".")).place(x=165,y=350)
customtkinter.CTkButton(master=frame,text="/",font=("serif",20,"bold"),width=65,height=35,command=lambda: show("/")).place(x=240,y=350)
customtkinter.CTkButton(master=frame,text="Enter",font=("serif",20,"bold"),width=290,height=35,command=lambda: calculate()).place(x=15,y=400)




root.mainloop()
